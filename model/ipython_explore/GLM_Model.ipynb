# %%
import numpy as np
import statsmodels.api as sm
from scipy import stats
from matplotlib import pyplot as plt
import sklearn

import os
import psycopg2
import pandas as pd
from fetch_station import fetch_station

# Fetch all records for a single station (tfl_id == 5)
bike_data_bucketed = fetch_station('Washington, D.C.',17,15, 'max')

# %%
bike_data_bucketed.head()
# Out:
#                            station_id  bikes_available  slots_available  \
# bikes_timestamp
# 2010-10-06 12:30:00-04:00          17                3               12
# 2010-10-06 12:45:00-04:00          17                3               12
# 2010-10-06 13:00:00-04:00          17                3               13
# 2010-10-06 13:15:00-04:00          17                2               14
# 2010-10-06 13:30:00-04:00          17                1               14
#
#                              weather_timestamp        summary precipintensity  \
# bikes_timestamp
# 2010-10-06 12:30:00-04:00  2010-10-06 16:00:00       Overcast               0
# 2010-10-06 12:45:00-04:00  2010-10-06 16:00:00       Overcast               0
# 2010-10-06 13:00:00-04:00  2010-10-06 17:00:00  Partly Cloudy               0
# 2010-10-06 13:15:00-04:00  2010-10-06 17:00:00  Partly Cloudy               0
# 2010-10-06 13:30:00-04:00  2010-10-06 17:00:00  Partly Cloudy               0
#
#                            precipprob preciptype  precipaccumulation  \
# bikes_timestamp
# 2010-10-06 12:30:00-04:00           0        NaN                 NaN
# 2010-10-06 12:45:00-04:00           0        NaN                 NaN
# 2010-10-06 13:00:00-04:00           0        NaN                 NaN
# 2010-10-06 13:15:00-04:00           0        NaN                 NaN
# 2010-10-06 13:30:00-04:00           0        NaN                 NaN
#
#                            temperature
# bikes_timestamp
# 2010-10-06 12:30:00-04:00        57.48
# 2010-10-06 12:45:00-04:00        57.48
# 2010-10-06 13:00:00-04:00        57.90
# 2010-10-06 13:15:00-04:00        57.90
# 2010-10-06 13:30:00-04:00        57.90

# %%
# Calculate the percent full 
#first convert to arrays so that Python doesn't do integer division
bikes_available=np.asarray(bike_data_bucketed["bikes_available"], dtype=np.float32)
slots_available=np.asarray(bike_data_bucketed["slots_available"], dtype=np.float32)

# Fix for Convergence Issues Using MLE, Option 1: Zero Entries -> 0.01 or Option 2: All Entries += 0.01 (Similar Results)
bikes_available[bikes_available == 0] = 0.01
slots_available[slots_available == 0] = 0.01

#bikes_available = bikes_available+0.01
#slots_available = slots_available+0.01

# Creating list of [success , failure] outcomes
bikes_slots_available=np.asarray(zip(bikes_available,slots_available))

# create log odds ratio of bikes to slots
phat = bikes_available / (bikes_available + slots_available) 
logodds = np.log(phat/(1-phat))

# Creating Lags of Bike and Slot Variables
bikes_available_lag0 = bikes_available[1:]
bikes_available_lag1 = bikes_available[0:len(bikes_available)-1]
slots_available_lag1 = slots_available[0:len(slots_available)-1]
bikes_slots_available_lag1 = bikes_slots_available[1:]

# Calculated the lag-log-odds ratio 
phat_lag1 = (bikes_available_lag1) / (bikes_available_lag1+slots_available_lag1)
#print "phat_lag1" + str(phat_lag1)
#print len(phat_lag1)

logodds_lag1 = np.log( phat_lag1 / (1-phat_lag1) )


# Add Constant to Exogenous Variables
logodds_lag1_cons = sm.add_constant(logodds_lag1, prepend=False)


# Fit Binomial Regression.  Coefficients constant in time

glm_binom = sm.GLM(bikes_slots_available_lag1, logodds_lag1_cons, family=sm.families.Binomial())

results = glm_binom.fit()

print results.summary()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           ['y1', 'y2']   No. Observations:                79334
# Model:                            GLM   Df Residuals:                    79332
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -1.7023e+05
# Date:                Fri, 16 Aug 2013   Deviance:                   1.1367e+05
# Time:                        22:04:11   Pearson chi2:                 1.14e+06
# No. Iterations:                     8
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.8546      0.001    609.560      0.000         0.852     0.857
# const         -0.0214      0.002    -12.104      0.000        -0.025    -0.018
# ==============================================================================

# %%
import datetime
import patsy
from patsy.contrasts import Treatment

# %%
# This model includes month effects and one previous time point
##### previous time point is very significant predictor; months are not



month_ref = 2
# Set up data frame with one lagged time point and a constant
data = pd.DataFrame(logodds_lag1_cons, columns = ["logodds", "constant"])

# Strip month information from original timestamp variable
month = pd.DatetimeIndex(bike_data_bucketed.index).month # this is a numpy.ndarray

# Create contrast matrix
levels = range(12)
contrast = Treatment(reference=month_ref).code_without_intercept(levels)

# Encode dummy matrix
month_dummy = contrast.matrix[month-1, :]

#drop first row because of lagged variable
month_dummy_lagged = month_dummy[1:, :]

month_list = ['jan','feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
# This j skips the column for the" reference level in the contrast matrix
j = 0
for i in range(12):
    if i != month_ref:
        data[month_list[i]] = month_dummy_lagged[:,i-j]
    else:
        j = 1
        
#run model
#glm_binom_2 = sm.GLM(bikes_slots_available_lag1, data, family=sm.families.Binomial())

#results = glm_binom_2.fit()

#print results.summary()

# %%
# Extract time of day from original data in 1 hour buckets
time_of_day = pd.DatetimeIndex(bike_data_bucketed.index).hour
#logodds_lag_data.head()

levels = list(range(0,24))
contrast = Treatment(reference=0).code_without_intercept(levels)
#print contrast.matrix
time_dummy = contrast.matrix[time_of_day, :]
time_dummy_lagged = time_dummy[1:, :]

# Midnight is reference variable

data['1AM'] = time_dummy_lagged[:,0]
data['2AM'] = time_dummy_lagged[:,1]
data['3AM'] = time_dummy_lagged[:,2]
data['4AM'] = time_dummy_lagged[:,3]
data['5AM'] = time_dummy_lagged[:,4]
data['6AM'] = time_dummy_lagged[:,5]
data['7AM'] = time_dummy_lagged[:,6]
data['8AM'] = time_dummy_lagged[:,7]
data['9AM'] = time_dummy_lagged[:,8]
data['10AM'] = time_dummy_lagged[:,9]
data['11AM'] = time_dummy_lagged[:,10]
data['12PM'] = time_dummy_lagged[:,11]
data['1PM'] = time_dummy_lagged[:,12]
data['2PM'] = time_dummy_lagged[:,13]
data['3PM'] = time_dummy_lagged[:,14]
data['4PM'] = time_dummy_lagged[:,15]
data['5PM'] = time_dummy_lagged[:,16]
data['6PM'] = time_dummy_lagged[:,17]
data['7PM'] = time_dummy_lagged[:,18]
data['8PM'] = time_dummy_lagged[:,19]
data['9PM'] = time_dummy_lagged[:,20]
data['10PM'] = time_dummy_lagged[:,21]
data['11PM'] = time_dummy_lagged[:,22]


#glm_binom_3 = sm.GLM(bikes_slots_available_lag1, data, family=sm.families.Binomial())

#results = glm_binom_3.fit()

#print results.summary()

# %%
#model with seasonal effects instead of monthly effects
#not working yet

#reset data so that it does not include month
#data = pd.DataFrame(logodds_lag1, columns = ["logodds", "constant"])
season = []
#create seasonal indicator variable
for i in range(0,len(month)):
    # winter
    if month[i]==0 | month[i] == 1 | month[i]==11 :
        try:
            season.append(0)
        except:
            print i
            break
    # spring
    elif month[i]==2 | month[i] == 3 | month[i] == 4:
        try:
            season.append(1)
        except:
            print i
            break
    # summer
    elif month[i]==5 | month[i] == 6 | month[i] == 7:
        try:
            season.append(2)
        except:
            print ":(" +str(i)
            break
    # fall
    elif month[i]==8 | month[i] == 9 | month[i] == 10:
        try:
            season.append(3)
        except:
            print i
            break

#make dummy variables for season

levels = [0,1,2,3]
contrast = Treatment(reference=0).code_without_intercept(levels)
#print contrast.matrix
season_df = pd.DataFrame(season)
season_dummy = contrast.matrix[season_df-1, :]

#drop first row because of lagged variable
season_dummy = season_dummy[1:, :]

# %%
# incorporate day of week
day_of_week = pd.DatetimeIndex(bike_data_bucketed.index).weekday

levels = list(range(0,7))
contrast = Treatment(reference=0).code_without_intercept(levels)

day_dummy = contrast.matrix[day_of_week, :]
day_dummy = day_dummy[1:, :]

weekend_dummy = []

for i in range(1,len(day_of_week)):
    if day_of_week[i] == 5 or day_of_week[i] == 6:
        weekend_dummy.append(1)
    else:
        weekend_dummy.append(0)

# Monday is the reference variable
data['TUES'] = day_dummy[:,0]
data['WED'] = day_dummy[:,1]
data['THUR'] = day_dummy[:,2]
data['FRI'] = day_dummy[:,3]
data['SAT'] = day_dummy[:,4]
data['SUN'] = day_dummy[:,5]

data['weekend'] = weekend_dummy

glm_binom_3 = sm.GLM(bikes_slots_available_lag1, data, family=sm.families.Binomial())

results = glm_binom_3.fit()

print results.summary()
# Out:
# 48942
# 48941
# [ 0.  0.  1.  0.  0.  0.]
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           ['y1', 'y2']   No. Observations:                48941
# Model:                            GLM   Df Residuals:                    48901
# Model Family:                Binomial   Df Model:                           39
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -68068.
# Date:                Tue, 30 Jul 2013   Deviance:                       11566.
# Time:                        19:14:32   Pearson chi2:                 1.24e+05
# No. Iterations:                   101
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# logodds        0.9365      0.003    306.473      0.000         0.931     0.942
# constant      -0.0016      0.026     -0.063      0.950        -0.052     0.048
# jul            0.0027      0.022      0.125      0.901        -0.040     0.046
# aug            0.0084      0.022      0.383      0.702        -0.034     0.051
# sep            0.0075      0.022      0.340      0.734        -0.036     0.050
# oct            0.0092      0.022      0.418      0.676        -0.034     0.052
# nov            0.0054      0.022      0.246      0.806        -0.038     0.048
# dec           -0.0573      0.083     -0.690      0.490        -0.220     0.106
# apr           -0.0144      0.023     -0.630      0.529        -0.059     0.030
# may            0.0045      0.022      0.206      0.837        -0.038     0.047
# jun           -0.0014      0.022     -0.063      0.949        -0.044     0.041
# 1AM           -0.0060      0.020     -0.305      0.761        -0.044     0.032
# 2AM            0.0039      0.020      0.198      0.843        -0.034     0.042
# 3AM            0.0049      0.020      0.249      0.803        -0.033     0.043
# 4AM            0.0027      0.020      0.135      0.892        -0.036     0.041
# 5AM           -0.0028      0.020     -0.143      0.886        -0.041     0.036
# 6AM           -0.0049      0.020     -0.248      0.804        -0.043     0.034
# 7AM           -0.0059      0.020     -0.299      0.765        -0.044     0.033
# 8AM            0.0056      0.019      0.288      0.773        -0.033     0.044
# 9AM            0.0062      0.019      0.320      0.749        -0.032     0.044
# 10AM           0.0077      0.019      0.398      0.691        -0.030     0.045
# 11AM           0.0287      0.019      1.489      0.137        -0.009     0.066
# 12PM           0.0168      0.019      0.872      0.383        -0.021     0.055
# 1PM           -0.0180      0.019     -0.941      0.347        -0.056     0.020
# 2PM            0.0131      0.019      0.683      0.495        -0.024     0.051
# 3PM           -0.0198      0.019     -1.034      0.301        -0.057     0.018
# 4PM           -0.0423      0.019     -2.214      0.027        -0.080    -0.005
# 5PM           -0.0438      0.019     -2.299      0.021        -0.081    -0.006
# 6PM           -0.0229      0.019     -1.198      0.231        -0.060     0.015
# 7PM           -0.0104      0.019     -0.542      0.588        -0.048     0.027
# 8PM           -0.0308      0.019     -1.603      0.109        -0.068     0.007
# 9PM           -0.0314      0.019     -1.626      0.104        -0.069     0.006
# 10PM          -0.0160      0.019     -0.827      0.408        -0.054     0.022
# 11PM          -0.0015      0.019     -0.078      0.938        -0.040     0.036
# weekend    -1.362e+10   2.79e+11     -0.049      0.961     -5.61e+11  5.33e+11
# TUES          -0.0011      0.010     -0.109      0.913        -0.021     0.019
# WED           -0.0016      0.010     -0.154      0.878        -0.022     0.019
# THUR           0.0044      0.010      0.425      0.671        -0.016     0.025
# FRI            0.0076      0.010      0.733      0.464        -0.013     0.028
# SAT         1.362e+10   2.79e+11      0.049      0.961     -5.33e+11  5.61e+11
# SUN         1.362e+10   2.79e+11      0.049      0.961     -5.33e+11  5.61e+11
# ==============================================================================

# %%
#goal: calculate the monthly average number of bikes

month_series= pd.Series(month)

month_series.value_counts()
# Out:
# 5     5950
# 8     5835
# 10    5784
# 6     5755
# 9     5701
# 11    5612
# 4     5594
# 7     5072
# 3     2518
# 12     863
# dtype: int64

# %%
# AR(3) model

# function from energy team to create matrix of predictors
def change_mat(ts, binom, d):
    """Recieve a time series and a markov delay period.
       Return a matix of that design."""
    n=len(ts)
    x = np.array(ts[(d-1):n-1])
    for r in range(2,d+1):
        b = np.array(ts[(d-r):(n-r)])
        x = np.concatenate([x.reshape(len(x),-1),b.reshape(len(b),-1)],axis=1)
    y = binom[d:]
    return x, y

pred_ar3, outcome_ar3 = change_mat(logodds, bikes_slots_available, 3)

glm_ar3 = sm.GLM(outcome_ar3, pred_ar3, family=sm.families.Binomial())

results = glm_ar3.fit()

print results.summary()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           ['y1', 'y2']   No. Observations:                48681
# Model:                            GLM   Df Residuals:                    48678
# Model Family:                Binomial   Df Model:                            2
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -67540.
# Date:                Sun, 28 Jul 2013   Deviance:                       11283.
# Time:                        01:54:43   Pearson chi2:                 1.38e+05
# No. Iterations:                    22
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.0267      0.008    135.548      0.000         1.012     1.041
# x2            -0.1038      0.009    -11.434      0.000        -0.122    -0.086
# x3             0.0184      0.006      2.843      0.004         0.006     0.031
# ==============================================================================

# %%
# vary coefficients based on time of day
# start with a model that has two sets of coefficients per day- one for midnight to noon, one for noon to midnight
all_time_dummy = numpy.append(time_dummy,numpy.zeros([len(time_dummy),1]),1)

# recode all_time_dummy to be 1 if the observations between midnight and 1 a.m. (this happens when all other columns of all_time_dummy sum to 0)
for i in range(len(all_time_dummy[:,0])):
    if np.sum(all_time_dummy[i,:]) == 0:
        all_time_dummy[i,23] = 1

# create lagged version of time dummy matrix
all_time_dummy_lagged = all_time_dummy[1:,:]

# create matrix of zeros and ones to indicate which time period a point falls into
morning = np.sum(all_time_dummy_lagged[:,0:8], axis=1)
midday = np.sum(all_time_dummy_lagged[:,8:16], axis=1)
evening = np.sum(all_time_dummy_lagged[:,16:23], axis=1)

print morning[1:10]

# multiply predictor variable by each column of created 0/1 matrix
# want to do this for each lagged time variable- start with only one previous time point
morn_logodds = pd.DataFrame(morning * logodds_lag1, columns = ["morn_logodds"])
print morn_logodds.head()
mid_logodds = pd.DataFrame(midday * logodds_lag1, columns= ["mid_logodds"])
eve_logodds = pd.DataFrame(evening * logodds_lag1, columns = ["eve_logodds"])

# remove original lagged variable, add new versions that are multiplied by time of day indicator
colnames = set(data.columns)
colnames.remove("logodds")

ar1_pred = data.ix[:, colnames]
ar1_pred = pd.concat([ar1_pred, morn_logodds, mid_logodds, eve_logodds], axis=1)

        
# fit model
glm_ar1_timevary = sm.GLM(bikes_slots_available_lag1, ar1_pred, family=sm.families.Binomial())

results = glm_ar1_timevary.fit()

print results.summary()

# use result as predictor in model
# Out:
# [ 0.  0.  0.  0.  0.  0.  0.  0.  0.]
#    I_morn
# 0      -0
# 1      -0
# 2      -0
# 3      -0
# 4      -0
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           ['y1', 'y2']   No. Observations:                98019
# Model:                            GLM   Df Residuals:                    97983
# Model Family:                Binomial   Df Model:                           35
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -2.2052e+05
# Date:                Wed, 07 Aug 2013   Deviance:                   1.5564e+05
# Time:                        00:15:39   Pearson chi2:                 7.74e+05
# No. Iterations:                     8
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# 11PM          -0.2365      0.009    -25.961      0.000        -0.254    -0.219
# constant       0.3773      0.008     48.882      0.000         0.362     0.392
# 3AM           -0.3263      0.010    -33.322      0.000        -0.345    -0.307
# sep           -0.0771      0.008     -9.145      0.000        -0.094    -0.061
# apr           -0.0551      0.007     -7.696      0.000        -0.069    -0.041
# 2AM           -0.3177      0.010    -32.576      0.000        -0.337    -0.299
# 12PM          -0.6372      0.010    -61.777      0.000        -0.657    -0.617
# 7PM           -0.4943      0.010    -50.240      0.000        -0.514    -0.475
# 5AM           -0.3381      0.010    -34.409      0.000        -0.357    -0.319
# 3PM           -0.7657      0.011    -69.844      0.000        -0.787    -0.744
# 6PM           -0.4921      0.010    -47.813      0.000        -0.512    -0.472
# 4AM           -0.3285      0.010    -33.418      0.000        -0.348    -0.309
# 2PM           -0.6974      0.011    -65.665      0.000        -0.718    -0.677
# 7AM           -0.3861      0.009    -40.934      0.000        -0.405    -0.368
# 5PM           -0.5511      0.011    -50.163      0.000        -0.573    -0.530
# aug           -0.0841      0.008    -10.446      0.000        -0.100    -0.068
# 6AM           -0.3565      0.010    -36.778      0.000        -0.376    -0.338
# 4PM           -0.7445      0.011    -66.366      0.000        -0.766    -0.723
# 1PM           -0.6778      0.010    -64.726      0.000        -0.698    -0.657
# 9AM           -0.6882      0.009    -72.455      0.000        -0.707    -0.670
# 10AM          -0.5003      0.010    -48.569      0.000        -0.520    -0.480
# 8AM           -0.5586      0.009    -61.738      0.000        -0.576    -0.541
# 11AM          -0.5723      0.010    -55.837      0.000        -0.592    -0.552
# oct           -0.0260      0.008     -3.408      0.001        -0.041    -0.011
# 9PM           -0.3673      0.009    -38.881      0.000        -0.386    -0.349
# may           -0.0700      0.007     -9.810      0.000        -0.084    -0.056
# jun           -0.0909      0.007    -12.509      0.000        -0.105    -0.077
# 10PM          -0.2811      0.009    -30.548      0.000        -0.299    -0.263
# jul           -0.1219      0.007    -16.495      0.000        -0.136    -0.107
# nov            0.0364      0.006      6.081      0.000         0.025     0.048
# 8PM           -0.4438      0.010    -46.090      0.000        -0.463    -0.425
# 1AM           -0.2532      0.010    -26.324      0.000        -0.272    -0.234
# dec            0.0457      0.006      7.645      0.000         0.034     0.057
# I_morn         0.9525      0.003    357.500      0.000         0.947     0.958
# I_mid          0.6927      0.002    287.011      0.000         0.688     0.697
# I_eve          0.7735      0.003    301.210      0.000         0.768     0.779
# ==============================================================================

# %%
#pickling to send stuff to Scott

import cPickle
cPickle.dump(phat_lag1, open("phatlag1.pkl", "wb"))

bike_data_bucketed_lag = bike_data_bucketed.ix[1:,:]
timestamps_lag1 = pd.DatetimeIndex(bike_data_bucketed_lag.index)
cPickle.dump(timestamps_lag1, open("timestampslag1.pkl", "wb"))

# %%
# number of coefficient buckets depends on user input
# vary coefficients based on time of day

all_time_dummy = numpy.append(time_dummy,numpy.zeros([len(time_dummy),1]),1)

# recode all_time_dummy to be 1 if the observations between midnight and 1 a.m. (this happens when all other columns of all_time_dummy sum to 0)
for i in range(len(all_time_dummy[:,0])):
    if np.sum(all_time_dummy[i,:]) == 0:
        all_time_dummy[i,23] = 1

# create lagged version of time dummy matrix
all_time_dummy_lagged = all_time_dummy[1:,:]

# create matrix of zeros and ones to indicate which time period a point falls into

n_time_buckets = 3
step1 = np.zeros((all_time_dummy_lagged.shape[0], n_time_buckets))
for i in range(0, 24, 24/n_time_buckets):
    step1[:,i/(24/n_time_buckets)] = np.sum(all_time_dummy_lagged[:,i: i + 24/n_time_buckets], axis = 1)


# multiply predictor variable by each column of created 0/1 matrix
# want to do this for each lagged time variable- start with only one previous time point
for j in range(3):
    for i in range(0, n_time_buckets):
        next_col = pd.DataFrame(step1[:,i]*logodds_lag1, columns = ["logodds_lag_" + str(j + 1) + "_time_bucket_" + str(i + 1)])
        data = pd.concat((data, next_col), axis = 1)


# remove original lagged variable, add new versions that are multiplied by time of day indicator
colnames = set(data.columns)
colnames.remove("logodds")

ar1_pred = data.ix[:, colnames]
        


# use result as predictor in model

# %%
ar1_pred.columns
# Out:
# Index([u'constant', u'logodds_lag_1_time_bucket_3', u'sep', u'apr', u'logodds_lag_1_time_bucket_2', u'feb', u'aug', u'logodds_lag_1_time_bucket_1', u'jan', u'logodds_lag_3_time_bucket_1', u'logodds_lag_3_time_bucket_2', u'logodds_lag_3_time_bucket_3', u'may', u'jun', u'logodds_lag_2_time_bucket_1', u'jul', u'logodds_lag_2_time_bucket_2', u'logodds_lag_2_time_bucket_3', u'nov', u'oct', u'dec'], dtype=object)

# %%
# fit model
glm_ar1_timevary = sm.GLM(bikes_slots_available_lag1, ar1_pred, family=sm.families.Binomial())

results = glm_ar1_timevary.fit()

print results.summary()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           ['y1', 'y2']   No. Observations:                79334
# Model:                            GLM   Df Residuals:                    79319
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -1.6860e+05
# Date:                Fri, 16 Aug 2013   Deviance:                   1.1041e+05
# Time:                        22:22:13   Pearson chi2:                 8.89e+05
# No. Iterations:                   101
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# constant                       -0.0832      0.007    -12.511      0.000        -0.096    -0.070
# logodds_lag_1_time_bucket_3  -8.87e+06   1.38e+07     -0.642      0.521      -3.6e+07  1.82e+07
# sep                            -0.0161      0.009     -1.701      0.089        -0.035     0.002
# apr                            -0.0125      0.009     -1.318      0.188        -0.031     0.006
# logodds_lag_1_time_bucket_2 -1.985e+10      4e+10     -0.496      0.620     -9.82e+10  5.85e+10
# feb                             0.0173      0.009      1.900      0.057        -0.001     0.035
# aug                            -0.0216      0.009     -2.439      0.015        -0.039    -0.004
# logodds_lag_1_time_bucket_1  4.786e+10   9.59e+10      0.499      0.618      -1.4e+11  2.36e+11
# jan                             0.0551      0.009      6.206      0.000         0.038     0.072
# logodds_lag_3_time_bucket_1 -2.395e+10    4.8e+10     -0.499      0.618     -1.18e+11  7.02e+10
# logodds_lag_3_time_bucket_2  9.959e+09      2e+10      0.498      0.618     -2.92e+10  4.91e+10
# logodds_lag_3_time_bucket_3  1.478e+07   2.26e+07      0.654      0.513     -2.95e+07  5.91e+07
# may                            -0.0029      0.009     -0.306      0.760        -0.021     0.016
# jun                            -0.0239      0.010     -2.496      0.013        -0.043    -0.005
# logodds_lag_2_time_bucket_1 -2.392e+10   4.79e+10     -0.499      0.618     -1.18e+11     7e+10
# jul                            -0.0264      0.009     -2.848      0.004        -0.045    -0.008
# logodds_lag_2_time_bucket_2  9.887e+09      2e+10      0.494      0.621     -2.93e+10  4.91e+10
# logodds_lag_2_time_bucket_3  -5.91e+06   8.82e+06     -0.670      0.503     -2.32e+07  1.14e+07
# nov                             0.0110      0.008      1.343      0.179        -0.005     0.027
# oct                             0.0089      0.009      1.010      0.313        -0.008     0.026
# dec                             0.0523      0.008      6.509      0.000         0.037     0.068
# ===============================================================================================
